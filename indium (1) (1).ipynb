# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

url = "https://en.wikipedia.org/wiki/List_of_prime_ministers_of_India"

r = requests.get(url).text

soup = BeautifulSoup(r, 'html.parser')

indiatable=soup.find('table',{'class':"wikitable"})

df=pd.read_html(str(indiatable))
# convert list to dataframe
df=pd.DataFrame(df[0])
df
df.columns=["No","No.1","Portrait","Name","Party","Took office","Left office","Time in office","Lok Sabha[e]","Ministry","Appointed by","NotNeeded"]
df[["Name","Party","Took office","Left office"]]
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df1=df[["Name","Party","Took office","Left office"]]

# %%
df1
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df1["Took office"]=df1["Took office"].str.replace("[§]","")
# Out:
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/1513708803.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1["Took office"]=df1["Took office"].str.replace("[§]","")
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/1513708803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Took office"]=df1["Took office"].str.replace("[§]","")

# %%
df1["Took office"]=df1["Took office"].str.replace("[[]]","")
# Out:
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/4115760168.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1["Took office"]=df1["Took office"].str.replace("[[]]","")
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/4115760168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Took office"]=df1["Took office"].str.replace("[[]]","")

# %%
df1
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df1["Left office"]=df1["Left office"].str.replace("[RES]","").replace("[NC]","").replace("†","")
# Out:
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/580992419.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1["Left office"]=df1["Left office"].str.replace("[RES]","").replace("[NC]","").replace("†","")
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/580992419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Left office"]=df1["Left office"].str.replace("[RES]","").replace("[NC]","").replace("†","")

# %%
df1
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df1["Left office"]=df1["Left office"].str.replace("†","")
# Out:
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/1784069235.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Left office"]=df1["Left office"].str.replace("†","")

# %%
df1
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df1["Left office"]=df1["Left office"].str.replace("[[]]","")
# Out:
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/776306457.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1["Left office"]=df1["Left office"].str.replace("[[]]","")
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/776306457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Left office"]=df1["Left office"].str.replace("[[]]","")

# %%
df1
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df1["Left office"]=df1["Left office"].str.replace("[NC]","")
# Out:
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/3697359744.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1["Left office"]=df1["Left office"].str.replace("[NC]","")
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/3697359744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Left office"]=df1["Left office"].str.replace("[NC]","")

# %%
df1
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df1["Left office"]=df1["Left office"].str.replace("[[]]","")
# Out:
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/776306457.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1["Left office"]=df1["Left office"].str.replace("[[]]","")
# /var/folders/8c/tdnsn9_94gq59j8yvnssq74r0000gp/T/ipykernel_7565/776306457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Left office"]=df1["Left office"].str.replace("[[]]","")

# %%
df1
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df1=df1.drop(26)

# %%
df1
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df1['Left office'].mask(df1['Left office'] == '10 ovember 1990', '10 November 1990', inplace=True)

# %%
df1
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df1['Left office']=pd.to_datetime(df1['Left office'],infer_datetime_format=True)

# %%
df1
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df1['Took office']=pd.to_datetime(df1['Took office'],infer_datetime_format=True)

# %%
df1
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df2 = df1[["Name","Party","Took office","Left office"]]

# %%
df2
# Out:
#                                              Name  \
# 0                     Jawaharlal Nehru(1889–1964)
# 1                     Jawaharlal Nehru(1889–1964)
# 2                     Jawaharlal Nehru(1889–1964)
# 3                     Jawaharlal Nehru(1889–1964)
# 4                     Gulzarilal Nanda(1898–1998)
# 5                  Lal Bahadur Shastri(1904–1966)
# 6                     Gulzarilal Nanda(1898–1998)
# 7                        Indira Gandhi(1917–1984)
# 8                        Indira Gandhi(1917–1984)
# 9                        Indira Gandhi(1917–1984)
# 10                       Morarji Desai(1896–1995)
# 11              Chaudhary Charan Singh(1902–1987)
# 12                       Indira Gandhi(1917–1984)
# 13                        Rajiv Gandhi(1944–1991)
# 14                        Rajiv Gandhi(1944–1991)
# 15             Vishwanath Pratap Singh(1931–2008)
# 16                     Chandra Shekhar(1927–2007)
# 17  Pamulaparthi Venkata Narasimha Rao(1921–2004)
# ...

# %%
df2['Name']=df1['Name'].str.split('(').str[0]
df2['Party']=df1['Party'].str.split('(').str[0]

# %%
df2
# Out:
#                                    Name                      Party  \
# 0                      Jawaharlal Nehru   Indian National Congress
# 1                      Jawaharlal Nehru   Indian National Congress
# 2                      Jawaharlal Nehru   Indian National Congress
# 3                      Jawaharlal Nehru   Indian National Congress
# 4                      Gulzarilal Nanda   Indian National Congress
# 5                   Lal Bahadur Shastri   Indian National Congress
# 6                      Gulzarilal Nanda   Indian National Congress
# 7                         Indira Gandhi   Indian National Congress
# 8                         Indira Gandhi  Indian National Congress
# 9                         Indira Gandhi  Indian National Congress
# 10                        Morarji Desai               Janata Party
# 11               Chaudhary Charan Singh              Janata Party
# 12                        Indira Gandhi  Indian National Congress
# ...

# %%
from sqlalchemy import create_engine
create=create_engine("mysql+pymysql://root:Deepak24@localhost/india")
df2.to_sql('pm',create,if_exists='replace',index=False)
